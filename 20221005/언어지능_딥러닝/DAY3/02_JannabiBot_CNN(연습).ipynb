  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNMHLWO5U3&Signature=0K8MNagPplHcCIsfvgZToYxGk8Y%3D&x-amz-security-token=FwoGZXIvYXdzECkaDKn2xtt0C3zTEst27CK%2BAV8S80vJkbxzMXL7%2Fz2yG26fRgFKOAXTGRih0KkWMiR970XLtbRKCBd1HvTMRoPrhBqlhu4WgVsfOHLRgBlJktVpN%2FWHLHD4vj9mk75EsZet0xzkRqmU75BzI2NwBU2q40Vbpm010lXdajJiGmR9RUTODQJins2RGDDA%2FJwFor3DQYBytyRZ6mfgjtPigtPpbBU9HmfMGTnIL7MtmH%2BfSLLQhpH9E0CDfZm1UGbjZXiU9co%2FXlYHyfemXHQF1b4o4%2FD0mQYyLfGWRco2E%2F1GmFVqrom8RGHw9uznw711dCSA4mutH0eS1jTfrgWldT0tDbMqIA%3D%3D&Expires=1664958315
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.217.104.4
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.217.104.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  23.0MB/s    in 2.1s
#
# 2022-10-05 08:05:45 (23.0 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/v0.6.0/scripts/mecab.sh)
# https://github.com/konlpy/konlpy/issues/395#issue-1099168405 - 2022.01.11
# Done
# Install mecab-python
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.
# light 버전 작성 : Dogdriip님 ( https://github.com/Dogdriip )
# 문제를 해결해주신 combacsa님 감사합니다.

# %%
def mecabsplit(mecab_tagger,inputs, pos):
    r=[]
    inputs = mecab_tagger.parse(inputs)
    t = inputs.split('\n')[:-2]
    for i in t:
        field = i.split('\t')
        if field[1].split(',')[-1] is not '*':
            r.extend( [ (x.split('/')[0],x.split('/')[1]) for x in field[1].split(',')[-1].split('+') ] )
        else:
            r.append( (field[0],field[1].split(',')[0]) )
    if pos:
        return r
    else:
        return [ x[0] for x in r ]
    return r

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable # tensor라고 생각하면 됨
import pickle
import MeCab

tagger = MeCab.Tagger()

# %%
class CNN_Text(nn.Module):
    
    def __init__(self, embed_num, class_num, ):
        super(CNN_Text, self).__init__()
        
        # 단어 사전 크기
        V = embed_num # 전체 단어의 개수
        # 임베딩벡터 크기
        D = 100 #args.embed_dim
        # 분류하고자 하는 클래스의 개수
        C = class_num # 3 => intent 개수
        # 입력 채널 수
        Ci = 1
        # 출력 채널 수
        Co = 20 #args.kernel_num
        # 커널(필터) 사이즈
        Ks = [1,2,3] # 문장 사이즈가 작기때문에 커널도 작게 잡음

        self.embed = nn.Embedding(V, D)
        # padding numbers for (height,width)
        self.convs1 = nn.ModuleList([nn.Conv2d(Ci, Co, (K, D), padding=(2,0)) for K in Ks])
        # dropout 설정
        self.dropout = nn.Dropout(0.2)
        # FC 레이어
        self.fc1 = nn.Linear(len(Ks)*Co, C)

    def forward(self, x):
        x = self.embed(x)  # (B, W, D)
        
        # 입력 x를 4D로 변환
        x = x.unsqueeze(1)  # (B(batch), Ci(input channel), W(sent), D(dimension))
        # output = F.relu(x) -> B x Co x W x 1
        # max_pool1D는 3D 입력만 받음 -> size 1인 차원을 제거(squeeze)
        x = [F.relu(conv(x)).squeeze(3) for conv in self.convs1]  # [(B, Co, W), ...]*len(Ks)
        
        # (B x Co x 1) -> size 1인 차원을 제거(squeeze)
        x = [F.max_pool1d(i, i.size(2)).squeeze(2) for i in x]  # [(B, Co), ...]*len(Ks)
        
        # concatenate
        x = torch.cat(x, 1) # 합쳐진 차원을 

        x = self.dropout(x)  # (B, len(Ks)*Co)
        logit = self.fc1(x)  
        return logit

# %%
# 학습데이터에 나타난 단어 사전
content_vocab = {'unk':0}
# 의도 레이블 사전
intent_vocab={}
# 의도 클래스
intent_list=[]

data_intent=''
intent_idx=0
vocab_idx=1

for line in open('/content/gdrive/My Drive/Colab Notebooks/aivle/data/jannabi/mydata.txt','r',encoding='utf-8'):
    line = line.strip().split('\t')
    if len(line)>1:
        intent=line[1]
        if intent not in intent_vocab:
            intent_vocab[intent]=intent_idx
            intent_list.append(intent)
            intent_idx +=1
    else:
        line = mecabsplit(tagger,line[0],False)
        for it in line:
            if it not in content_vocab:
                content_vocab[it] = vocab_idx
                vocab_idx +=1

# %%
cnn = CNN_Text(vocab_idx,intent_idx) # 모델 생성
print(vocab_idx, intent_idx) # 파일에 나타난 단어수, 의도 갯수(Class 갯수)
optimizer = torch.optim.Adam(cnn.parameters())
cnn.train()
# Out:
# 34 3
# CNN_Text(
#   (embed): Embedding(34, 100)
#   (convs1): ModuleList(
#     (0): Conv2d(1, 20, kernel_size=(1, 100), stride=(1, 1), padding=(2, 0))
#     (1): Conv2d(1, 20, kernel_size=(2, 100), stride=(1, 1), padding=(2, 0))
#     (2): Conv2d(1, 20, kernel_size=(3, 100), stride=(1, 1), padding=(2, 0))
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=60, out_features=3, bias=True)
# )

# %%
epoch = 10
for e in range(epoch):
    totalloss = 0
    for line in open('/content/gdrive/My Drive/Colab Notebooks/aivle/data/jannabi/mydata.txt','r',encoding='utf-8'):
        line = line.strip().split('\t')
    
        if len(line)> 1:
            target = Variable(torch.LongTensor([intent_vocab[line[1]]]))
            continue

        optimizer.zero_grad() # 학습시키기 전에 gradient 버퍼 값들을 0으로 리셋

        cont = []
        line = mecabsplit(tagger,line[0],False)
        for it in line:
            cont.append(content_vocab[it])
        # view : 원소의 수를 유지하면서 텐서를 reshape, 텐서의 첫번째 차원을 1로 reshape
        cont = Variable(torch.LongTensor(cont)).view(1,-1) # 입력값, 읽어들인 토큰 값
        pred = cnn(cont)

        loss = F.cross_entropy(pred,target)
        totalloss += loss.data
        loss.backward()
        optimizer.step()
    print (e, 'epoch')
    print('loss : {:.3f}'.format(totalloss.numpy()))
# Out:
# 0 epoch
# loss : 61.863
# 1 epoch
# loss : 12.028
# 2 epoch
# loss : 2.631
# 3 epoch
# loss : 1.941
# 4 epoch
# loss : 1.298
# 5 epoch
# loss : 0.604
# 6 epoch
# loss : 0.967
# 7 epoch
# loss : 0.371
# 8 epoch
# loss : 0.299
# 9 epoch
# loss : 0.232

# %%
response = []
for line in open('/content/gdrive/My Drive/Colab Notebooks/aivle/data/jannabi/response.txt','r',encoding='utf-8'): # 응답 문장
    line=line.strip()
    response.append(line)

# %%
cnn.eval()
for line in open('/content/gdrive/My Drive/Colab Notebooks/aivle/data/jannabi/testdata.txt','r',encoding='utf-8'):
    line = line.strip()
    
    line = mecabsplit(tagger,line,False)
    cont = []
    for it in line:
        if it in content_vocab:
            cont.append(content_vocab[it]) # cont에는 입력문에 나타난 단어들의 index 저장됨 예) 0~31
        else:
            cont.append(content_vocab['unk'])
    cont = Variable(torch.LongTensor(cont)).view(1,-1)
    pred = cnn(cont)
    v,i = torch.max(pred,1) # pred는 (p1, p2) 즉, 클래스별 확률 v: 둘중 큰값 i:큰값 클래스의 인덱스
    
    print('input : ',line)
    # 3개 클래스의 확률값
    probs = torch.nn.functional.softmax(pred,dim=-1).data.numpy()[0]
    print ([probs[0], probs[1], probs[2]])
    print('intent : ',intent_list[int(i)])
    print(response[int(i)])
    print()
# Out:
# input :  ['잔나비', '오늘', '스', '케', '쥴', '보이', '어', '주', '어']
# [0.9930566, 0.0015212946, 0.0054220855]
# intent :  ASK_SCHEDULES
# 잔나비에 대한 최신 스케쥴입니다.
#
# input :  ['잔나비', '데뷔', '일', '은', '?']
# [0.036737036, 0.9360255, 0.027237466]
# intent :  ASK_DEBUTDATE
# 잔나비의 데뷔일은 2014년 4월 28일 입니다.
#
# input :  ['잔나비', '노래', '틀', '어', '주', '어']
# [0.0030469664, 0.00044030466, 0.9965127]
# intent :  ASK_MUSIC
# 잔나비의 노래를 재생합니다.
