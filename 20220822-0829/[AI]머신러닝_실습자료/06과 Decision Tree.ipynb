# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) import

# %%
#라이브러리들을 불러오자.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import warnings    # 경고메시지 제외
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### (2) 데이터 준비

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_simple2.CSV"
data = pd.read_csv(path)
data.head()
# Out:
#    Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  JobSatisfaction  \
# 0          0   33                 7             817    Male                3
# 1          0   35                18            1412    Male                4
# 2          0   42                 6            1911    Male                1
# 3          0   46                 2            1204  Female                1
# 4          1   22                 4             593    Male                3
#
#   MaritalStatus  MonthlyIncome OverTime  PercentSalaryHike  TotalWorkingYears
# 0       Married          11691       No                 11                 14
# 1        Single           9362       No                 11                 10
# 2       Married          13348       No                 13                 18
# 3       Married          17048       No                 23                 28
# 4        Single           3894       No                 16                  4

# %% [markdown]
# |	구분	|	변수 명	|	내용	|	type	|	비고	|
# |	----	|	----	|	----	|	----	|	----	|
# |	**Target**	|	**Attrition**	|	이직여부	|	범주	| 1- 이직, 0- 잔류		|
# |	feature	|	Age	|	나이	|	숫자	|		|
# |	feature	|	BusinessTravel	|	출장빈도	|	범주	|Travel_Rarely, Travel_Frequently, Non-Travel		|
# |	feature	|	Department	|	부서	|	범주	|Research & Development, Sales, Human Resources	|
# |	feature	|	DistanceFromHome	|	집-직장 거리	|	숫자	|	마일	|
# |	feature	|	EmployeeNumber	|	사번	|	??	|		|
# |	feature	|	Gender	|	성별	|	범주	| Male, Female		|
# |	feature	|	JobSatisfaction	|	직무 만족도	|	범주	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	feature	|	MaritalStatus	|	결혼상태	|	범주	| Single, Married, Divorced		|
# |	feature	|	MonthlyIncome	|	월급	|	숫자	| 달러	|
# |	feature	|	OverTime	|	야근여부	|	범주	|	Yes, No	|
# |	feature	|	PercentSalaryHike	|	전년대비 급여인상율	|	숫자	|	%	|
# |	feature	|	RelationshipSatisfaction	|	관계만족도	|	범주	| 1 Low, 2 Medium, 3 High, 4 Very High|
# |	feature	|	StockOptionLevel	|	스톡옵션레벨	|	범주	| 0 : 없음, 1~3 (클수록 스톡옵션을 많이 받음|
# |	feature	|	TotalWorkingYears	|	총 경력 연수	|	숫자	|		|
# |	feature	|	WorkLifeBalance	|	워라밸	|	범주	| 1 Low, 2 Medium, 3 High, 4 Very High

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# ### (1) 데이터 정리

# %%
data.drop('EmployeeNumber', axis = 1, inplace = True)

# %% [markdown]
# ### (2) 데이터분할1 : x, y 나누기

# %%
# x와 y 분리
target = 'Attrition'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (3) NA 조치

# %% [markdown]
# ### (4) 가변수화

# %%
cat_cols = ['Gender','JobSatisfaction','MaritalStatus','OverTime']
x = pd.get_dummies(x, columns = cat_cols, drop_first = True)

# %% [markdown]
# ### (5) 데이터분할2 : train : validation 나누기

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = .3, random_state = 2022)

# %% [markdown]
# ### (6) Scaling

# %% [markdown]
# ## 3.모델링

# %% [markdown]
# ### (1) 필요한 함수 불러오기
#
# * DecisionTree
#     * DecisionTreeClassifier : 분류
#     * DecisionTreeRegressor : 회귀

# %%
# 모델링을 위해
from sklearn.tree import DecisionTreeClassifier, plot_tree

# 평가를 위해.
from sklearn.metrics import *

# %% [markdown]
# ### (2) 선언

# %%
model = DecisionTreeClassifier() #  default로 만들면 가장 복잡한 tree가 됨 !

# %% [markdown]
# ### (3) 모델링(학습)

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### (4) 검증 : 예측

# %%
pred = model.predict(x_val)

# %% [markdown]
# ### (5) 검증 : 평가

# %% [markdown]
# * confusion matrix

# %%
print(confusion_matrix(y_val, pred))
# Out:
# [[260  40]
#  [ 37  22]]

# %% [markdown]
# * classification report

# %%
print(classification_report(y_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87       300
#            1       0.35      0.37      0.36        59
#
#     accuracy                           0.79       359
#    macro avg       0.62      0.62      0.62       359
# weighted avg       0.79      0.79      0.79       359

# %% [markdown]
# ## 4.Hyper Parameter
#
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %% [markdown]
# * max_depth : 트리의 깊이(크기를 결정)
# * min_samples_leaf : leaf 노드의 최소 데이터 건수
#     * leaf 노드는 y를 예측하는데 사용되는데, 데이터가 적으면 예측 결과에 대해 신뢰도가 떨어질 수 있다.

# %% [markdown]
# ### (1) max_depth

# %%
# max_depth = 2
model1 = DecisionTreeClassifier(max_depth = 2)
model1.fit(x_train, y_train)
pred1 = model1.predict(x_val)
print(classification_report(y_val, pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       300
#            1       0.47      0.31      0.37        59
#
#     accuracy                           0.83       359
#    macro avg       0.67      0.62      0.64       359
# weighted avg       0.81      0.83      0.81       359

# %%
# max_depth = 5
model2 = DecisionTreeClassifier(max_depth = 5)
model2.fit(x_train, y_train)
pred2 = model2.predict(x_val)
print(classification_report(y_val, pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       300
#            1       0.46      0.29      0.35        59
#
#     accuracy                           0.83       359
#    macro avg       0.66      0.61      0.63       359
# weighted avg       0.80      0.83      0.81       359

# %% [markdown]
# ### (2) min_samples_leaf

# %%
# min_samples_leaf = 30
model3 = DecisionTreeClassifier(min_samples_leaf = 30)
model3.fit(x_train, y_train)
pred3 = model3.predict(x_val)
print(classification_report(y_val, pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       300
#            1       0.52      0.22      0.31        59
#
#     accuracy                           0.84       359
#    macro avg       0.69      0.59      0.61       359
# weighted avg       0.81      0.84      0.81       359

# %%
# min_samples_leaf = 60
model4 = DecisionTreeClassifier(min_samples_leaf = 60)
model4.fit(x_train, y_train)
pred4 = model4.predict(x_val)
print(classification_report(y_val, pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       300
#            1       0.47      0.31      0.37        59
#
#     accuracy                           0.83       359
#    macro avg       0.67      0.62      0.64       359
# weighted avg       0.81      0.83      0.81       359

# %% [markdown]
# ## 5.Decision Tree 내부 들여다 보기

# %% [markdown]
# ### (1) 모델 시각화

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html

# %%
y_train.head()

# %%
# 시각화
from sklearn.tree import plot_tree

# Decision Tree는 모델을 시각화 할 수 있습니다.
plot_tree(model,                                    #만든 모델 이름
               feature_names = list(x_train),     #Feature 이름, list(x_train)
               class_names = ['Stay', 'Leave'],      #Target(Class) 이름  -> 0을  'Stay'로 바꿔주고 1을 'Leave'로 바꿔줘
               filled = True);

# %% [markdown]
# #### 1) max_depth = 2

# %%
plt.figure(figsize = (20,10)) # 그림 사이즈 조절
plot_tree(model1, feature_names = list(x_train), 
               class_names= ['Stay', 'Leave'], filled = True, fontsize = 20);

# %% [markdown]
# #### 2) max_depth = 5

# %%
plt.figure(figsize = (30,10)) # 그림 사이즈 조절
plot_tree(model2, feature_names = list(x_train), 
               class_names= ['Stay', 'Leave'], filled = True, fontsize = 8);

# %% [markdown]
# #### 3) min_samples_leaf = 30

# %%
plt.figure(figsize = (30,15)) # 그림 사이즈 조절
plot_tree(model3, feature_names = list(x_train), 
               class_names= ['Stay', 'Leave'], filled = True, fontsize = 8);

# %% [markdown]
# #### 4) min_samples_leaf = 60

# %%
plt.figure(figsize = (20,10)) # 그림 사이즈 조절
plot_tree(model4, feature_names = list(x_train), 
               class_names= ['Stay', 'Leave'], filled = True, fontsize = 10);

# %% [markdown]
# ### (2) 변수 중요도

# %%
# 변수 중요도
print(list(x_train))
print(model.feature_importances_)
# Out:
# ['Age', 'DistanceFromHome', 'MonthlyIncome', 'PercentSalaryHike', 'TotalWorkingYears', 'Gender_Male', 'JobSatisfaction_2', 'JobSatisfaction_3', 'JobSatisfaction_4', 'MaritalStatus_Married', 'MaritalStatus_Single', 'OverTime_Yes']
# [0.15906429 0.12992304 0.30473137 0.08630534 0.12934483 0.02366808
#  0.01064179 0.01365696 0.0327086  0.0232238  0.02614502 0.06058689]

# %% [markdown]
# * 변수중요도 그래프 그리기 함수 만들기

# %%
def plot_feature_importance(importance, names):
    feature_importance = np.array(importance)
    feature_names = np.array(names)

    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)

    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_df.reset_index(drop=True, inplace = True)

    plt.figure(figsize=(10,8))
    sns.barplot(x='feature_importance', y='feature_names', data = fi_df)

    plt.xlabel('FEATURE IMPORTANCE')
    plt.ylabel('FEATURE NAMES')
    plt.grid()

    return fi_df

# %%
result = plot_feature_importance(model.feature_importances_, list(x_train))
# 모델 전체에서 가장 중요한 변수 : montlyIncome  /  처음 노드를 분리할 때 가장 좋은 변수 : Overtime_Yes

# %%
result
# Out:
#             feature_names  feature_importance
# 0           MonthlyIncome            0.304731
# 1                     Age            0.159064
# 2        DistanceFromHome            0.129923
# 3       TotalWorkingYears            0.129345
# 4       PercentSalaryHike            0.086305
# 5            OverTime_Yes            0.060587
# 6       JobSatisfaction_4            0.032709
# 7    MaritalStatus_Single            0.026145
# 8             Gender_Male            0.023668
# 9   MaritalStatus_Married            0.023224
# 10      JobSatisfaction_3            0.013657
# 11      JobSatisfaction_2            0.010642

# %% [markdown]
# * 1~10까지 depth를 늘려가면서 성능측정(f1)

# %%
depth = range(1,11)
f1 = []
for d in depth :
    m = DecisionTreeClassifier(max_depth = d)
    m.fit(x_train, y_train)
    p = m.predict(x_val)
    f1.append( f1_score(y_val, p) )

# %%
plt.plot(depth, f1, marker = 's')
plt.grid()
plt.show()

# %% [markdown]
# 실전에서는 방금 수행한 작업으로 for loop로 이용하기 보다는 Grid Search, Random Search 방식의 튜닝을 수행하게 됩니다.

# %% [markdown]
# ## 6.실습 : 이동통신 가입 고객 이탈 예측

# %% [markdown]
# * 여러분은 OO 통신회사 데이터분석가 입니다.
# * 회사는 약정기간이 끝난 고객이 번호이동(이탈)해 가는 문제를 해결하고자 합니다.
# * 그래서 여러분에게, 어떤 고객이 번호이동(이탈)해 가는지 예측 모델링을 의뢰하였습니다.

# %% [markdown]
# ![](https://d18lkz4dllo6v2.cloudfront.net/cumulus_uploads/entry/23964/mobile%20phones.png)

# %% [markdown]
# * 변수설명
#     * COLLEGE : 대학 졸업여부
#     * INCOME : 연수입
#     * OVERAGE : 월평균 초과사용 시간(분)
#     * LEFTOVER : 월평균 잔여시간비율(%)
#     * HOUSE : 집값
#     * HANDSET_PRICE : 스마트폰 가격
#     * OVER_15MINS_CALLS_PER_MONTH : 월평균 장기통화(15분이상) 횟수
#     * AVERAGE_CALL_DURATION : 평균 통화 시간
#     * REPORTED_SATISFACTION : 만족도 설문조사 결과
#     * REPORTED_USAGE_LEVEL : 사용도 자가진단 결과
#     * CONSIDERING_CHANGE_OF_PLAN : 향후 변경계획 설문조사 결과
#     * CHURN : 이탈(번호이동) 여부 (Target 변수)

# %% [markdown]
# ### (1) 데이터 전처리

# %%
# 데이터를 불러옵시다.
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/mobile_cust_churn.csv'
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    id  COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 0   1        0   31953        0         6  313378            161
# 1   2        1   36147        0        13  800586            244
# 2   3        1   27273      230         0  305049            201
# 3   4        0  120070       38        33  788235            780
# 4   5        1   29215      208        85  224784            241
#
#    OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION REPORTED_SATISFACTION  \
# 0                            0                      4                 unsat
# 1                            0                      6                 unsat
# 2                           16                     15                 unsat
# 3                            3                      2                 unsat
# 4                           21                      1            very_unsat
#
#   REPORTED_USAGE_LEVEL CONSIDERING_CHANGE_OF_PLAN  CHURN
# 0               little                         no   STAY
# 1               little                considering   STAY
# 2          very_little                    perhaps   STAY
# 3            very_high                considering  LEAVE
# 4               little              never_thought   STAY

# %% [markdown]
# * 변수정리 : 불필요한 변수를 정리합시다.
#     * 식별자 : 일련번호, 주민번호, 전화번호, 고객ID, 사번
#     * 시계열 데이터 중 : 어떤 기간동안 거의 변화가 없는 값.(변동이 거의 없는) 값.

# %%
drop_cols = ['id']
data.drop(drop_cols, axis = 1, inplace = True )

# %% [markdown]
# * x, y 분할

# %%
target = 'CHURN'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# * 가변수화

# %%
dumm_cols = ['REPORTED_SATISFACTION','REPORTED_USAGE_LEVEL','CONSIDERING_CHANGE_OF_PLAN']
x = pd.get_dummies(x, columns = dumm_cols, drop_first = True)

# %% [markdown]
# * train, val 분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x,y,test_size = 0.3)

# %% [markdown]
# ### (2) 모델링
# * max_depth를 1~10 사이에서 조정하며 모델을 생성하고 성능을 비교해 봅시다.
# * min_samples_leaf 를 20 ~ 300 사이에서 조정하며 모델을 생성하고 성능을 비교해 봅시다.

# %%
model = DecisionTreeClassifier(max_depth=3, min_samples_leaf=20)
model1.fit(x_train, y_train)
pred1 = model1.predict(x_val)
print(classification_report(y_val, pred1))
# Out:
#               precision    recall  f1-score   support
#
#        LEAVE       0.74      0.59      0.66      3004
#         STAY       0.66      0.79      0.72      2996
#
#     accuracy                           0.69      6000
#    macro avg       0.70      0.69      0.69      6000
# weighted avg       0.70      0.69      0.69      6000

# %%
model2 = DecisionTreeClassifier(max_depth=8)
model2.fit(x_train, y_train)
pred2 = model2.predict(x_val)
print(classification_report(y_val, pred2))
# Out:
#               precision    recall  f1-score   support
#
#        LEAVE       0.68      0.76      0.72      3004
#         STAY       0.73      0.64      0.68      2996
#
#     accuracy                           0.70      6000
#    macro avg       0.70      0.70      0.70      6000
# weighted avg       0.70      0.70      0.70      6000

# %%
model3 = DecisionTreeClassifier(max_depth=8, min_samples_leaf=40)
model3.fit(x_train, y_train)
pred3 = model3.predict(x_val)
print(classification_report(y_val, pred3))
# Out:
#               precision    recall  f1-score   support
#
#        LEAVE       0.70      0.70      0.70      3004
#         STAY       0.70      0.70      0.70      2996
#
#     accuracy                           0.70      6000
#    macro avg       0.70      0.70      0.70      6000
# weighted avg       0.70      0.70      0.70      6000

# %% [markdown]
# ### (3) 최적의 모델에 대해 시각화 및 변수 중요도를 살펴 봅시다.

# %%
# model1 => max_depth=3, min_samples_leaf=20
plt.figure(figsize=(15, 10))
plot_tree(model1,                                    #만든 모델 이름
               feature_names = list(x_train),     #Feature 이름, list(x_train)
               class_names = ['Stay', 'Leave'],      #Target(Class) 이름  -> 0을  'Stay'로 바꿔주고 1을 'Leave'로 바꿔줘
               filled = True);
plt.show()

result = plot_feature_importance(model1.feature_importances_, list(x_train))
result
# Out:
#                                feature_names  feature_importance
# 0                                    OVERAGE            0.361607
# 1                                      HOUSE            0.313971
# 2                                     INCOME            0.241177
# 3                                   LEFTOVER            0.083245
# 4                                    COLLEGE            0.000000
# 5                  REPORTED_USAGE_LEVEL_high            0.000000
# 6              CONSIDERING_CHANGE_OF_PLAN_no            0.000000
# 7   CONSIDERING_CHANGE_OF_PLAN_never_thought            0.000000
# 8     CONSIDERING_CHANGE_OF_PLAN_considering            0.000000
# 9           REPORTED_USAGE_LEVEL_very_little            0.000000
# 10            REPORTED_USAGE_LEVEL_very_high            0.000000
# 11               REPORTED_USAGE_LEVEL_little            0.000000
# 12            REPORTED_SATISFACTION_very_sat            0.000000
# 13          REPORTED_SATISFACTION_very_unsat            0.000000
# 14               REPORTED_SATISFACTION_unsat            0.000000
# 15                 REPORTED_SATISFACTION_sat            0.000000
# 16                     AVERAGE_CALL_DURATION            0.000000
# 17               OVER_15MINS_CALLS_PER_MONTH            0.000000
# 18                             HANDSET_PRICE            0.000000
# 19        CONSIDERING_CHANGE_OF_PLAN_perhaps            0.000000

# %%
# model2 => max_depth=8
plt.figure(figsize=(15, 10))
plot_tree(model2,                                    #만든 모델 이름
               feature_names = list(x_train),     #Feature 이름, list(x_train)
               class_names = ['Stay', 'Leave'],      #Target(Class) 이름  -> 0을  'Stay'로 바꿔주고 1을 'Leave'로 바꿔줘
               filled = True);
plt.show()

result = plot_feature_importance(model2.feature_importances_, list(x_train))
result
# Out:
#                                feature_names  feature_importance
# 0                                    OVERAGE            0.361607
# 1                                      HOUSE            0.313971
# 2                                     INCOME            0.241177
# 3                                   LEFTOVER            0.083245
# 4                                    COLLEGE            0.000000
# 5                  REPORTED_USAGE_LEVEL_high            0.000000
# 6              CONSIDERING_CHANGE_OF_PLAN_no            0.000000
# 7   CONSIDERING_CHANGE_OF_PLAN_never_thought            0.000000
# 8     CONSIDERING_CHANGE_OF_PLAN_considering            0.000000
# 9           REPORTED_USAGE_LEVEL_very_little            0.000000
# 10            REPORTED_USAGE_LEVEL_very_high            0.000000
# 11               REPORTED_USAGE_LEVEL_little            0.000000
# 12            REPORTED_SATISFACTION_very_sat            0.000000
# 13          REPORTED_SATISFACTION_very_unsat            0.000000
# 14               REPORTED_SATISFACTION_unsat            0.000000
# 15                 REPORTED_SATISFACTION_sat            0.000000
# 16                     AVERAGE_CALL_DURATION            0.000000
# 17               OVER_15MINS_CALLS_PER_MONTH            0.000000
# 18                             HANDSET_PRICE            0.000000
# 19        CONSIDERING_CHANGE_OF_PLAN_perhaps            0.000000

# %%
# model3 => max_depth=8, min_samples_leaf=40
plt.figure(figsize=(15, 10))
plot_tree(model3,                                    #만든 모델 이름
               feature_names = list(x_train),     #Feature 이름, list(x_train)
               class_names = ['Stay', 'Leave'],      #Target(Class) 이름  -> 0을  'Stay'로 바꿔주고 1을 'Leave'로 바꿔줘
               filled = True);
plt.show()

result = plot_feature_importance(model3.feature_importances_, list(x_train))
# feature_importances_ 는 모델에 사용된 변수들의 중요도를 나타냄, 사용되지 않은 변수들은 값이 없음 !
result
# Out:
#                                feature_names  feature_importance
# 0                                    OVERAGE            0.334834
# 1                                      HOUSE            0.262092
# 2                                     INCOME            0.211568
# 3                                   LEFTOVER            0.144195
# 4                              HANDSET_PRICE            0.022777
# 5                                    COLLEGE            0.011174
# 6                OVER_15MINS_CALLS_PER_MONTH            0.004342
# 7                      AVERAGE_CALL_DURATION            0.003826
# 8     CONSIDERING_CHANGE_OF_PLAN_considering            0.001739
# 9                  REPORTED_SATISFACTION_sat            0.001347
# 10            REPORTED_SATISFACTION_very_sat            0.001065
# 11                 REPORTED_USAGE_LEVEL_high            0.000562
# 12               REPORTED_USAGE_LEVEL_little            0.000480
# 13          REPORTED_SATISFACTION_very_unsat            0.000000
# 14            REPORTED_USAGE_LEVEL_very_high            0.000000
# 15          REPORTED_USAGE_LEVEL_very_little            0.000000
# 16               REPORTED_SATISFACTION_unsat            0.000000
# 17  CONSIDERING_CHANGE_OF_PLAN_never_thought            0.000000
# 18             CONSIDERING_CHANGE_OF_PLAN_no            0.000000
# 19        CONSIDERING_CHANGE_OF_PLAN_perhaps            0.000000
