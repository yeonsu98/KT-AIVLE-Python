# %% [markdown]
# # Colab에서 MeCab 활용하기
#
#
# ##Colab 동작 OS 확인

# %%
# OS 확인
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.6 LTS

# %% [markdown]
# ## Google Drive 연결하기

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pwd
# !ls
# Out:
# /content
# gdrive	sample_data

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# 데이터 파일 압축해제 
import zipfile
import os

zip_file = '/content/gdrive/MyDrive/Colab Notebooks/aivle/data/data_model.zip'

with zipfile.ZipFile(zip_file) as z:
    z.extractall('/content/gdrive/MyDrive/Colab Notebooks/aivle/data')

os.remove(zip_file)

# %% [markdown]
# ##MeCab 설치하기

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 16.89 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# !pwd
# %cd Mecab-ko-for-Google-Colab
# Out:
# /content
# /content/Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab_light_220429.sh # 형태소 분석기 설치
# Out:
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.3 MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 67.0 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2022-09-30 02:45:03--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 18.205.93.0, 18.205.93.2, 18.205.93.1, ...
# Connecting to bitbucket.org (bitbucket.org)|18.205.93.0|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNPWVBHVCS&Signature=9bqXicCr1VI7Khix0dTTwKZJNus%3D&x-amz-security-token=FwoGZXIvYXdzEKz%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDOQ133oFag8IOaQxvyK%2BAXQW0fFWYQBGVRNc8WmD%2B4wBYCAS7I8PIIhQ86Un40lv%2FdoY2LxTiEGKWcyBOY24d2SJsJLKrnMyQF2cAl3K7cisi3QOq2WZ3rtztRTOxgunqZJpE%2BdFNrWw4nAo7Yq5EiyqaQTNeVCnDCgN5eMCbFi8kieLKk3sj3oRiZoJaIlIUcDPNF1hJ3WBdS%2ByTacpUfPVXjUL9SdV%2FoQU620etCpZ5%2Fhiu2U0RlbajnB%2BVK98c7zHj0IeeTl0waAj%2BWco1avZmQYyLcXGKJU6kBBcDViQMa9Gcm556MJGy%2BNbhS7nB2%2FZ7V9bMlB7L2lHSSOgzQY%2Bag%3D%3D&Expires=1664507101 [following]
# --2022-09-30 02:45:03--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNPWVBHVCS&Signature=9bqXicCr1VI7Khix0dTTwKZJNus%3D&x-amz-security-token=FwoGZXIvYXdzEKz%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDOQ133oFag8IOaQxvyK%2BAXQW0fFWYQBGVRNc8WmD%2B4wBYCAS7I8PIIhQ86Un40lv%2FdoY2LxTiEGKWcyBOY24d2SJsJLKrnMyQF2cAl3K7cisi3QOq2WZ3rtztRTOxgunqZJpE%2BdFNrWw4nAo7Yq5EiyqaQTNeVCnDCgN5eMCbFi8kieLKk3sj3oRiZoJaIlIUcDPNF1hJ3WBdS%2ByTacpUfPVXjUL9SdV%2FoQU620etCpZ5%2Fhiu2U0RlbajnB%2BVK98c7zHj0IeeTl0waAj%2BWco1avZmQYyLcXGKJU6kBBcDViQMa9Gcm556MJGy%2BNbhS7nB2%2FZ7V9bMlB7L2lHSSOgzQY%2Bag%3D%3D&Expires=1664507101
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 54.231.193.185
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|54.231.193.185|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  --.-KB/s    in 0.1s
#
# 2022-09-30 02:45:03 (11.0 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2022-09-30 02:46:42--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 18.205.93.1, 18.205.93.2, 18.205.93.0, ...
# Connecting to bitbucket.org (bitbucket.org)|18.205.93.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNMDCEBHSA&Signature=%2FfbGITi4v%2Be3iR3k81A3YX9MO34%3D&x-amz-security-token=FwoGZXIvYXdzEKz%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDKISJRe5DebCtKrufiK%2BAXwVZVFSVkwCvuH6H13kWb4ans49QEn4QzOlpuuWidCawyr9G2IlfBO4ExkF6yWVPugbrSDnHVqmcDklNiQ8%2BZ24cBkuu6cjQfz2tjUONYQYQ7pKZIutv%2BTEVU5Lc5pMq48Jl84JSCoa18kMzcM7vIqPHIwkGY5DdzKDfXYpqTlWDE%2B6Z9xhzCmEH3ipyBjE9FDp4OvHYir1HG3YOcjS08ah7FQs22%2BCPGQqtAp6jnRaWSTocAVWE7%2B2Zsqnl%2FQoqqrZmQYyLUHeh4sJuEmzI6HJ7sp2CXFQGzKSf41XAF42a%2Fuf%2F%2B4Bl4Ajob3EQixFkhzgoA%3D%3D&Expires=1664506930 [following]
# --2022-09-30 02:46:43--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNMDCEBHSA&Signature=%2FfbGITi4v%2Be3iR3k81A3YX9MO34%3D&x-amz-security-token=FwoGZXIvYXdzEKz%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDKISJRe5DebCtKrufiK%2BAXwVZVFSVkwCvuH6H13kWb4ans49QEn4QzOlpuuWidCawyr9G2IlfBO4ExkF6yWVPugbrSDnHVqmcDklNiQ8%2BZ24cBkuu6cjQfz2tjUONYQYQ7pKZIutv%2BTEVU5Lc5pMq48Jl84JSCoa18kMzcM7vIqPHIwkGY5DdzKDfXYpqTlWDE%2B6Z9xhzCmEH3ipyBjE9FDp4OvHYir1HG3YOcjS08ah7FQs22%2BCPGQqtAp6jnRaWSTocAVWE7%2B2Zsqnl%2FQoqqrZmQYyLUHeh4sJuEmzI6HJ7sp2CXFQGzKSf41XAF42a%2Fuf%2F%2B4Bl4Ajob3EQixFkhzgoA%3D%3D&Expires=1664506930
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.217.202.193
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.217.202.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  91.7MB/s    in 0.5s
#
# 2022-09-30 02:46:43 (91.7 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/v0.6.0/scripts/mecab.sh)
# https://github.com/konlpy/konlpy/issues/395#issue-1099168405 - 2022.01.11
# Done
# Install mecab-python
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.
# light 버전 작성 : Dogdriip님 ( https://github.com/Dogdriip )
# 문제를 해결해주신 combacsa님 감사합니다.

# %%
# 실행 테스트
import MeCab

# %%
tagger = MeCab.Tagger()

# %%
sentence = '이제 Colab에서 Mecab-ko-dic 사용이 가능합니다.'
print (tagger.parse(sentence))
# Mecab-ko-dic을 하나의 단어로 인식했으면 좋겠는데 ..
# Out:
# 이제	MAG,성분부사|시간부사,F,이제,*,*,*,*
# Colab	SL,*,*,*,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# Mecab	SL,*,*,*,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# ko	SL,*,*,*,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# dic	SL,*,*,*,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 가능	NNG,정적사태,T,가능,*,*,*,*
# 합니다	XSA+EF,*,F,합니다,Inflect,XSA,EF,하/XSA/*+ᄇ니다/EF/*
# .	SF,*,*,*,*,*,*,*
# EOS

# %%
sentence = '코로나 감염 뒤 4주 이상 후유증이 이어지는 현상을 롱코비드라고 부른다.'
print (tagger.parse(sentence))
# Out:
# 코로나	NNP,인명,F,코로나,*,*,*,*
# 감염	NNG,상태변화,T,감염,*,*,*,*
# 뒤	NNG,*,F,뒤,*,*,*,*
# 4	SN,*,*,*,*,*,*,*
# 주	NNBC,*,F,주,*,*,*,*
# 이상	NNG,*,T,이상,*,*,*,*
# 후유증	NNG,정적사태,T,후유증,Compound,*,*,후유/NNG/*+증/NNG/*
# 이	JKS,*,F,이,*,*,*,*
# 이어지	VV,*,F,이어지,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 현상	NNG,*,T,현상,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 롱	NNG,*,T,롱,*,*,*,*
# 코비	NNG,*,F,코비,Compound,*,*,코/NNG/*+비/NNG/*
# 드	VV,*,F,드,Inflect,VV,VV,들/VV/*
# 라고	EC,*,F,라고,*,*,*,*
# 부른다	VV+EF,*,F,부른다,Inflect,VV,EF,부르/VV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# EOS

# %%
sentence = '예일공중보건대학원 로버트슨 교수는 이미 코로나19가 팬데믹에서 엔데믹으로 전환 중이라고 말했다.'
print (tagger.parse(sentence))
# 예일공중보건대학원, 팬데믹 => 하나로 묶었으면 좋겠다..
# Out:
# 예	IC,*,F,예,*,*,*,*
# 일	NR,*,T,일,*,*,*,*
# 공중	NNG,*,T,공중,*,*,*,*
# 보건	NNG,행위,T,보건,*,*,*,*
# 대학원	NNG,*,T,대학원,Compound,*,*,대학/NNG/*+원/NNG/*
# 로버트슨	NNP,인명,T,로버트슨,*,*,*,*
# 교수	NNG,*,F,교수,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 이미	MAG,성분부사|시간부사,F,이미,*,*,*,*
# 코로나	NNP,인명,F,코로나,*,*,*,*
# 19	SN,*,*,*,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 팬데	NNBC+VCP+EC,*,F,팬데,Inflect,NNBC,EC,패/NNBC/*+이/VCP/*+ㄴ데/EC/*
# 믹	NNG,*,T,믹,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 엔데	NNP,인명,F,엔데,*,*,*,*
# 믹	NNG,*,T,믹,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 전환	NNG,행위,T,전환,*,*,*,*
# 중	NNB,*,T,중,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라고	EC,*,F,라고,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 했	XSV+EP,*,T,했,Inflect,XSV,EP,하/XSV/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# EOS

# %%
# 설치 후 Tagger 에러가 발생한 경우
# https://github.com/konlpy/konlpy/issues/144
#!git clone https://bitbucket.org/eunjeon/mecab-python-0.996.git
#import os
#os.chdir('mecab-python-0.996')
#!python setup.py build
#!python setup.py install

# %%
# !pwd
# Out:
# /content/Mecab-ko-for-Google-Colab

# %% [markdown]
# ### MeCab 사용자 사전 추가하기

# %%
# Mecab의 사전 디렉토리 => 실행하는 로직과 구분이 되어 있는..
# %cd /content/mecab-ko-dic-2.1.1-20180720/
# Out:
# /content/mecab-ko-dic-2.1.1-20180720

# %%
ls
# Out:
# aclocal.m4      EF.csv       MAJ.csv      NorthKorea.csv     tools/
# AUTHORS         EP.csv       Makefile     NP.csv             unk.def
# autogen.sh*     ETM.csv      Makefile.am  NR.csv             unk.dic
# ChangeLog       ETN.csv      Makefile.in  Person-actor.csv   user-dic/
# char.bin        feature.def  matrix.bin   Person.csv         VA.csv
# char.def        Foreign.csv  matrix.def   Place-address.csv  VCN.csv
# clean*          Group.csv    missing*     Place.csv          VCP.csv
# CoinedWord.csv  Hanja.csv    MM.csv       Place-station.csv  VV.csv
# config.log      IC.csv       model.bin    pos-id.def         VX.csv
# config.status*  Inflect.csv  model.def    Preanalysis.csv    Wikipedia.csv
# configure*      INSTALL      NEWS         README             XPN.csv
# configure.ac    install-sh*  NNBC.csv     rewrite.def        XR.csv
# COPYING         J.csv        NNB.csv      right-id.def       XSA.csv
# dicrc           left-id.def  NNG.csv      Symbol.csv         XSN.csv
# EC.csv          MAG.csv      NNP.csv      sys.dic            XSV.csv

# %%
# !ls user-dic/
# Out:
# nnp.csv  person.csv  place.csv	README.md

# %%
# 사용자 사전에 미리 등록되어있는 고유명사
# !cat user-dic/nnp.csv
# Out:
# 대우,,,,NNP,*,F,대우,*,*,*,*,*
# 구글,,,,NNP,*,T,구글,*,*,*,*,*

# %% [markdown]
# **1.Colab 안에서 직접 단어 추가하기**

# %%
# 사전에 등록할 단어 추가
# !echo "Mecab-ko-dic,,,,NNP,*,T,Mecab-ko-dic,*,*,*,*,*" >> user-dic/nnp.csv
# !cat user-dic/nnp.csv
# 마지막에 받침이 있는 글자는 T, 없으면 F
# Out:
# 대우,,,,NNP,*,F,대우,*,*,*,*,*
# 구글,,,,NNP,*,T,구글,*,*,*,*,*
# Mecab-ko-dic,,,,NNP,*,T,Mecab-ko-dic,*,*,*,*,*

# %%
#mv user-dic/nnp.csv /content/gdrive/'My Drive'/'Colab Notebooks'/

# %% [markdown]
# **2.텍스트 파일로 로컬에서 수정 후 추가하기**

# %%
# nnp.csv 파일 이동
# !mv /content/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv /content/gdrive/'My Drive'/'Colab Notebooks'/

# %% [markdown]
# #### Notepad++ 설치(사전에 추가할 내용 에디터)
# https://notepad-plus-plus.org/downloads/v8.4.6/

# %% [markdown]
# **로컬에서 nnp.csv 파일에 단어를 추가한 후에 구글드라이브에 업로드**

# %%
# 로컬에서 파일 수정 후 재 업로드
#!cat /content/gdrive/'My Drive'/'Colab Notebooks'/nng.csv
#!cat /content/gdrive/'My Drive'/'Colab Notebooks'/nnp.csv
# !cat /content/gdrive/'My Drive'/'Colab Notebooks'/aivle/DAY1/nng.csv
# !cat /content/gdrive/'My Drive'/'Colab Notebooks'/aivle/DAY1/nnp.csv
# Out:
# 팬데믹,,,,NNG,*,T,팬데믹,*,*,*,*,*
# 엔데믹,,,,NNG,*,T,엔데믹,*,*,*,*,*
# 롱코비드,,,,NNG,*,F,롱코비드,*,*,*,*,*대우,,,,NNP,*,F,대우,*,*,*,*,*
# 구글,,,,NNP,*,T,구글,*,*,*,*,*
# Mecab-ko-dic,,,,NNP,*,T,Mecab-ko-dic,*,*,*,*,*
# 예일공중보건대학원,,,,NNP,*,T,예일공중보건대학원,*,*,*,*,*
# 프리미어리그,,,,NNP,*,F,프리미어리그,*,*,*,*,*

# %%
sentence = '토트넘이 리그 4위로 21-22 프리미어리그 시즌을 마무리해서 UCL에 진출했다.'
print (tagger.parse(sentence))
# Out:
# 토트넘	NNP,*,T,토트넘,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 리그	NNG,*,F,리그,*,*,*,*
# 4	SN,*,*,*,*,*,*,*
# 위	NNBC,*,F,위,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 21	SN,*,*,*,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# 22	SN,*,*,*,*,*,*,*
# 프리미어	NNP,인명,F,프리미어,*,*,*,*
# 리그	NNG,*,F,리그,*,*,*,*
# 시즌	NNG,*,T,시즌,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 마무리	NNG,행위,F,마무리,*,*,*,*
# 해서	XSV+EC,*,F,해서,Inflect,XSV,EC,하/XSV/*+아서/EC/*
# UCL	SL,*,*,*,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 진출	NNG,행위,T,진출,*,*,*,*
# 했	XSV+EP,*,T,했,Inflect,XSV,EP,하/XSV/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# EOS

# %%
# 업로드된 수정 파일 이동
# !mv /content/gdrive/'My Drive'/'Colab Notebooks'/aivle/DAY1/nng.csv /content/mecab-ko-dic-2.1.1-20180720/user-dic/
# !mv /content/gdrive/'My Drive'/'Colab Notebooks'/aivle/DAY1/nnp.csv /content/mecab-ko-dic-2.1.1-20180720/user-dic/
# !ls user-dic/
# Out:
# nng.csv  nnp.csv  person.csv  place.csv  README.md

# %%
# !cat /content/mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv
# !cat /content/mecab-ko-dic-2.1.1-20180720/user-dic/nng.csv
# Out:
# 대우,,,,NNP,*,F,대우,*,*,*,*,*
# 구글,,,,NNP,*,T,구글,*,*,*,*,*
# Mecab-ko-dic,,,,NNP,*,T,Mecab-ko-dic,*,*,*,*,*
# 예일공중보건대학원,,,,NNP,*,T,예일공중보건대학원,*,*,*,*,*
# 프리미어리그,,,,NNP,*,F,프리미어리그,*,*,*,*,*팬데믹,,,,NNG,*,T,팬데믹,*,*,*,*,*
# 엔데믹,,,,NNG,*,T,엔데믹,*,*,*,*,*
# 롱코비드,,,,NNG,*,F,롱코비드,*,*,*,*,*

# %%
# 사용자사전 업데이트
# !bash ./tools/add-userdic.sh
# Out:
# generating userdic...
# nng.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/nng.csv ...
# done!
# nnp.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/nnp.csv ...
# done!
# person.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/person.csv ...
# done!
# place.csv
# /content/mecab-ko-dic-2.1.1-20180720/tools/../model.def is not a binary model. reopen it as text mode...
# reading /content/mecab-ko-dic-2.1.1-20180720/tools/../user-dic/place.csv ...
# done!
# test -z "model.bin matrix.bin char.bin sys.dic unk.dic" || rm -f model.bin matrix.bin char.bin sys.dic unk.dic
# /usr/local/libexec/mecab/mecab-dict-index -d . -o . -f UTF-8 -t UTF-8
# reading ./unk.def ... 13
# emitting double-array: 100% |###########################################|
# reading ./EF.csv ... 1820
# reading ./Inflect.csv ... 44820
# reading ./J.csv ... 416
# reading ./XSV.csv ... 23
# reading ./ETM.csv ... 133
# reading ./Person-actor.csv ... 99230
# reading ./user-person.csv ... 1
# reading ./Wikipedia.csv ... 36762
# reading ./Person.csv ... 196459
# reading ./NR.csv ... 482
# reading ./Place.csv ... 30303
# reading ./ETN.csv ... 14
# reading ./VCN.csv ... 7
# reading ./XPN.csv ... 83
# reading ./VX.csv ... 125
# reading ./XR.csv ... 3637
# reading ./MAG.csv ... 14242
# reading ./MM.csv ... 453
# reading ./VCP.csv ... 9
# reading ./EC.csv ... 2547
# reading ./user-nnp.csv ... 5
# reading ./XSN.csv ... 124
# reading ./NNP.csv ... 2371
# reading ./user-nng.csv ... 3
# reading ./NP.csv ... 342
# reading ./Foreign.csv ... 11690
# reading ./Preanalysis.csv ... 5
# reading ./Group.csv ... 3176
# reading ./VV.csv ... 7331
# reading ./Place-station.csv ... 1145
# reading ./NNG.csv ... 208524
# reading ./NorthKorea.csv ... 3
# reading ./MAJ.csv ... 240
# reading ./IC.csv ... 1305
# reading ./NNB.csv ... 140
# reading ./XSA.csv ... 19
# reading ./user-place.csv ... 2
# reading ./CoinedWord.csv ... 148
# reading ./Hanja.csv ... 125750
# reading ./NNBC.csv ... 677
# reading ./Symbol.csv ... 16
# reading ./VA.csv ... 2360
# reading ./Place-address.csv ... 19301
# reading ./EP.csv ... 51
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 3822x2693
# emitting matrix      : 100% |###########################################|
#
# done!
# echo To enable dictionary, rewrite /usr/local/etc/mecabrc as \"dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic\"
# To enable dictionary, rewrite /usr/local/etc/mecabrc as "dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic"

# %%
# 사전 리빌드
# !sudo make install
# Out:
# make[1]: Entering directory '/content/mecab-ko-dic-2.1.1-20180720'
# make[1]: Nothing to be done for 'install-exec-am'.
#  /bin/mkdir -p '/usr/local/lib/mecab/dic/mecab-ko-dic'
#  /usr/bin/install -c -m 644 model.bin matrix.bin char.bin sys.dic unk.dic left-id.def right-id.def rewrite.def pos-id.def dicrc '/usr/local/lib/mecab/dic/mecab-ko-dic'
# make[1]: Leaving directory '/content/mecab-ko-dic-2.1.1-20180720'

# %%
tagger = MeCab.Tagger()
# 사용자 사전 업데이트 확인
sentence = '코로나 감염 뒤 4주 이상 후유증이 이어지는 현상을 롱코비드라고 부른다.'
print (tagger.parse(sentence))
# Out:
# 코로나	NNP,인명,F,코로나,*,*,*,*
# 감염	NNG,상태변화,T,감염,*,*,*,*
# 뒤	NNG,*,F,뒤,*,*,*,*
# 4	SN,*,*,*,*,*,*,*
# 주	NNBC,*,F,주,*,*,*,*
# 이상	NNG,*,T,이상,*,*,*,*
# 후유증	NNG,정적사태,T,후유증,Compound,*,*,후유/NNG/*+증/NNG/*
# 이	JKS,*,F,이,*,*,*,*
# 이어지	VV,*,F,이어지,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 현상	NNG,*,T,현상,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 롱코비드	NNG,*,F,롱코비드,*,*,*,*,*
# 라고	VCP+EC,*,F,라고,Inflect,VCP,EC,이/VCP/*+라고/EC/*
# 부른다	VV+EF,*,F,부른다,Inflect,VV,EF,부르/VV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# EOS

# %%
sentence = '예일공중보건대학원 로버트슨 교수는 이미 코로나19가 팬데믹에서 엔데믹으로 전환 중이라고 말했다.'
print (tagger.parse(sentence))
# Out:
# 예일공중보건대학원	NNP,*,T,예일공중보건대학원,*,*,*,*,*
# 로버트슨	NNP,인명,T,로버트슨,*,*,*,*
# 교수	NNG,*,F,교수,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 이미	MAG,성분부사|시간부사,F,이미,*,*,*,*
# 코로나	NNP,인명,F,코로나,*,*,*,*
# 19	SN,*,*,*,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 팬데믹	NNG,*,T,팬데믹,*,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 엔데믹	NNG,*,T,엔데믹,*,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 전환	NNG,행위,T,전환,*,*,*,*
# 중	NNB,*,T,중,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라고	EC,*,F,라고,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 했	XSV+EP,*,T,했,Inflect,XSV,EP,하/XSV/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# EOS

# %%
sentence = '토트넘이 리그 4위로 21-22 프리미어리그 시즌을 마무리해서 UCL에 진출했다.'
print (tagger.parse(sentence))
# Out:
# 토트넘	NNP,*,T,토트넘,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 리그	NNG,*,F,리그,*,*,*,*
# 4	SN,*,*,*,*,*,*,*
# 위	NNBC,*,F,위,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 21	SN,*,*,*,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# 22	SN,*,*,*,*,*,*,*
# 프리미어리그	NNP,*,F,프리미어리그,*,*,*,*,*
# 시즌	NNG,*,T,시즌,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 마무리	NNG,행위,F,마무리,*,*,*,*
# 해서	XSV+EC,*,F,해서,Inflect,XSV,EC,하/XSV/*+아서/EC/*
# UCL	SL,*,*,*,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 진출	NNG,행위,T,진출,*,*,*,*
# 했	XSV+EP,*,T,했,Inflect,XSV,EP,하/XSV/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# EOS
